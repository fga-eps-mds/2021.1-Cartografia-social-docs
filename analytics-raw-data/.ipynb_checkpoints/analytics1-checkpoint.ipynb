# %% [markdown]
# # Analytics

# %% [markdown]
# #### Date: 2020/02
#
# #### SUMMARY:
#
# - This notebook represents the project quality analysis of the date exposed right above.

# %% [markdown]
# ### TEAM:
#
# ##### Semester: YYYY/0X
# ##### Professor: Hilmer Neri
#
# ##### Members:
#
# - Member x
# - Member y

# %% [markdown]
# ### LIBRARIES

# %%
# Deal with data
import pandas as pd
import numpy as np
import json
from glob import glob
import os

# Deal with API request
import urllib3
from urllib3 import request

# Deal with visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### GRAPH SETTINGS

# %%
# %config InlineBackend.figure_format ='retina'
sns.set(font_scale=1.5)
sns.set_style('darkgrid',
              {'xtick.bottom' : True,
               'ytick.left': True,
               'grid.linestyle':'--',
               'font.monospace': ['Computer Modern Typewriter'],
               'axes.edgecolor' : 'white'})

# %% [markdown]
# ### DATAFRAME SETTINGS

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ### SonarCloud

# %%
repos = [
    '2021.1-Cartografia-social-api-comunidades',
    '2021.1-Cartografia-social-api-gateway',
    '2021.1-Cartografia-social-api-mapas',
    '2021.1-Cartografia-social-api-midia',
    '2021.1-Cartografia-social-api-users',
    '2021.1-Cartografia-social-front'
]

language = [['2021.1-Cartografia-social-api-comunidades', 'ts'], 
            ['2021.1-Cartografia-social-api-gateway', 'ts'], 
            ['2021.1-Cartografia-social-api-mapas', 'ts'], 
            ['2021.1-Cartografia-social-api-midia', 'ts'], 
            ['2021.1-Cartografia-social-api-users', 'ts'], 
            ['2021.1-Cartografia-social-front', 'js']]

repos_language = {}

for item in language:
    repos_language[f"{item[0]}"] = item[1]

# %%
repos_language
# Out:
# {'2021.1-Cartografia-social-api-comunidades': 'ts',
#  '2021.1-Cartografia-social-api-gateway': 'ts',
#  '2021.1-Cartografia-social-api-mapas': 'ts',
#  '2021.1-Cartografia-social-api-midia': 'ts',
#  '2021.1-Cartografia-social-api-users': 'ts',
#  '2021.1-Cartografia-social-front': 'js'}

# %% [markdown]
# ##### Path to the folder with all your jsons

# %%
jsons = glob('**/*.json') # add the path here

# %%
def read_json(json_path):
    
    with open(json_path) as json_file:
        json_obj = json.load(json_file)
        
    return json_obj

def create_base_component_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        base_component = read_json(i)

        base_component_data = base_component['baseComponent']['measures']

        base_component_df = pd.DataFrame(base_component_data)

        base_component_df['filename'] = os.path.basename(i)

        df = df.append(base_component_df, ignore_index=True)
        
    aux_df = df['filename'].str.split(r"fga-eps-mds-2021_1-(.*?)_(.*?)_(.*?).json", expand=True)
    
    df['repository'] = aux_df[1]
    
    df['version'] = aux_df[3]
    
    df = df.sort_values(by=['repository', 'version'])
        
    return df

# %% [markdown]
# #### Create base component dataframe

# %%
base_component_df = create_base_component_df(jsons)
print(base_component_df)
# Out:
#                        metric value bestValue  \
# 92   duplicated_lines_density   0.0      True
# 93                  functions    35       NaN
# 94            security_rating   1.0      True
# 95                      files    30       NaN
# 96                 complexity    35       NaN
# 97                      ncloc   336       NaN
# 98         reliability_rating   1.0      True
# 99      comment_lines_density   0.0     False
# 47   duplicated_lines_density   0.0      True
# 48                  functions    16       NaN
# 49            security_rating   1.0      True
# 50                      files     8       NaN
# 51                 complexity    20       NaN
# 52                      ncloc   161       NaN
# 53                   coverage  68.0     False
# 54         reliability_rating   1.0      True
# 55      comment_lines_density   0.0     False
# 74   duplicated_lines_density   0.0      True
# 75                  functions    16       NaN
# 76            security_rating   1.0      True
# 77                      files     8       NaN
# 78                 complexity    20       NaN
# 79                      ncloc   161       NaN
# 80                   coverage  83.8     False
# 81         reliability_rating   1.0      True
# 82      comment_lines_density   0.0     False
# 100  duplicated_lines_density   0.0      True
# 101                 functions    21       NaN
# 102           security_rating   1.0      True
# 103                     files    10       NaN
# 104                complexity    25       NaN
# 105                     ncloc   196       NaN
# 106                  coverage  84.4     False
# 107        reliability_rating   1.0      True
# 108     comment_lines_density   0.0     False
# 65   duplicated_lines_density   0.0      True
# 66                  functions    31       NaN
# 67            security_rating   1.0      True
# 68                      files    12       NaN
# 69                 complexity    36       NaN
# 70                      ncloc   284       NaN
# 71                   coverage  85.9     False
# 72         reliability_rating   1.0      True
# 73      comment_lines_density   0.7     False
# 38   duplicated_lines_density   0.0      True
# 39                  functions    39       NaN
# 40            security_rating   1.0      True
# 41                      files    12       NaN
# 42                 complexity    45       NaN
# 43                      ncloc   334       NaN
# 44                   coverage  89.0     False
# 45         reliability_rating   1.0      True
# 46      comment_lines_density   1.2     False
# 109  duplicated_lines_density   0.0      True
# 110                 functions    44       NaN
# 111           security_rating   1.0      True
# 112                     files    12       NaN
# 113                complexity    56       NaN
# 114                     ncloc   393       NaN
# 115                  coverage  91.5     False
# 116        reliability_rating   1.0      True
# 117     comment_lines_density   1.5     False
# 83   duplicated_lines_density   0.0      True
# 84                  functions    54       NaN
# 85            security_rating   1.0      True
# 86                      files    13       NaN
# 87                 complexity    68       NaN
# 88                      ncloc   480       NaN
# 89                   coverage  82.4     False
# 90         reliability_rating   1.0      True
# 91      comment_lines_density   1.6     False
# 56   duplicated_lines_density   0.0      True
# 57                  functions    54       NaN
# 58            security_rating   1.0      True
# 59                      files    13       NaN
# 60                 complexity    68       NaN
# 61                      ncloc   482       NaN
# 62                   coverage  82.4     False
# 63         reliability_rating   1.0      True
# 64      comment_lines_density   1.6     False
# 198  duplicated_lines_density   0.2     False
# 199                 functions   130       NaN
# 200           security_rating   1.0      True
# 201                     files    38       NaN
# 202                complexity   144       NaN
# 203                     ncloc  1031       NaN
# 204        reliability_rating   1.0      True
# 205     comment_lines_density   0.2     False
# 136  duplicated_lines_density   0.0      True
# 137                 functions    36       NaN
# 138           security_rating   1.0      True
# 139                     files    13       NaN
# 140                complexity    36       NaN
# 141                     ncloc   429       NaN
# 142                  coverage  89.5     False
# 143        reliability_rating   1.0      True
# 144     comment_lines_density   0.5     False
# 163  duplicated_lines_density   0.2     False
# 164                 functions   130       NaN
# 165           security_rating   1.0      True
# 166                     files    38       NaN
# 167                complexity   144       NaN
# 168                     ncloc  1031       NaN
# 169        reliability_rating   1.0      True
# 170     comment_lines_density   0.2     False
# 154  duplicated_lines_density   0.0      True
# 155                 functions     5       NaN
# 156           security_rating   1.0      True
# 157                     files     1       NaN
# 158                complexity     5       NaN
# 159                     ncloc    46       NaN
# 160                  coverage  84.2     False
# 161        reliability_rating   1.0      True
# 162     comment_lines_density   0.0     False
# 180  duplicated_lines_density   0.0      True
# 181                 functions     9       NaN
# 182           security_rating   1.0      True
# 183                     files     4       NaN
# 184                complexity     9       NaN
# 185                     ncloc   121       NaN
# 186                  coverage  85.7     False
# 187        reliability_rating   1.0      True
# 188     comment_lines_density   0.0     False
# 127  duplicated_lines_density   0.0      True
# 128                 functions    15       NaN
# 129           security_rating   1.0      True
# 130                     files     6       NaN
# 131                complexity    15       NaN
# 132                     ncloc   184       NaN
# 133                  coverage  86.0     False
# 134        reliability_rating   1.0      True
# 135     comment_lines_density   1.1     False
# 118  duplicated_lines_density   0.0      True
# 119                 functions    19       NaN
# 120           security_rating   1.0      True
# 121                     files     8       NaN
# 122                complexity    19       NaN
# 123                     ncloc   239       NaN
# 124                  coverage  86.9     False
# 125        reliability_rating   1.0      True
# 126     comment_lines_density   0.8     False
# 206  duplicated_lines_density   0.0      True
# 207                 functions    23       NaN
# 208           security_rating   1.0      True
# 209                     files     8       NaN
# 210                complexity    23       NaN
# 211                     ncloc   282       NaN
# 212                  coverage  87.4     False
# 213        reliability_rating   1.0      True
# 214     comment_lines_density   0.7     False
# 189  duplicated_lines_density   0.0      True
# 190                 functions    30       NaN
# 191           security_rating   1.0      True
# 192                     files    12       NaN
# 193                complexity    30       NaN
# 194                     ncloc   367       NaN
# 195                  coverage  87.9     False
# 196        reliability_rating   1.0      True
# 197     comment_lines_density   0.5     False
# 145  duplicated_lines_density   0.0      True
# 146                 functions    30       NaN
# 147           security_rating   1.0      True
# 148                     files    12       NaN
# 149                complexity    30       NaN
# 150                     ncloc   367       NaN
# 151                  coverage  87.9     False
# 152        reliability_rating   1.0      True
# 153     comment_lines_density   0.5     False
# 215  duplicated_lines_density   0.0      True
# 216                 functions    36       NaN
# 217           security_rating   1.0      True
# 218                     files    14       NaN
# 219                complexity    36       NaN
# 220                     ncloc   450       NaN
# 221                  coverage  91.1     False
# 222        reliability_rating   1.0      True
# 223     comment_lines_density   0.4     False
# 224  duplicated_lines_density   0.0      True
# 225                 functions    36       NaN
# 226           security_rating   1.0      True
# 227                     files    16       NaN
# 228                complexity    36       NaN
# 229                     ncloc   462       NaN
# 230                  coverage  91.2     False
# 231        reliability_rating   1.0      True
# 232     comment_lines_density   0.4     False
# 171  duplicated_lines_density   0.0      True
# 172                 functions    40       NaN
# 173           security_rating   1.0      True
# 174                     files    20       NaN
# 175                complexity    40       NaN
# 176                     ncloc   551       NaN
# 177                  coverage  88.7     False
# 178        reliability_rating   1.0      True
# 179     comment_lines_density   0.4     False
# 242  duplicated_lines_density   0.0      True
# 243                 functions    19       NaN
# 244           security_rating   1.0      True
# 245                     files    20       NaN
# 246                complexity    19       NaN
# 247                     ncloc   214       NaN
# 248        reliability_rating   1.0      True
# 249     comment_lines_density   0.0     False
# 250  duplicated_lines_density   0.0      True
# 251                 functions    14       NaN
# 252           security_rating   1.0      True
# 253                     files     7       NaN
# 254                complexity    17       NaN
# 255                     ncloc   167       NaN
# 256                  coverage  93.6     False
# 257        reliability_rating   1.0      True
# 258     comment_lines_density   0.0     False
# 233  duplicated_lines_density   0.0      True
# 234                 functions    43       NaN
# 235           security_rating   1.0      True
# 236                     files    13       NaN
# 237                complexity    54       NaN
# 238                     ncloc   419       NaN
# 239                  coverage  88.4     False
# 240        reliability_rating   1.0      True
# 241     comment_lines_density   0.9     False
# 268  duplicated_lines_density   0.0      True
# 269                 functions    53       NaN
# 270           security_rating   1.0      True
# 271                     files    16       NaN
# 272                complexity    68       NaN
# 273                     ncloc   556       NaN
# 274                  coverage  87.5     False
# 275        reliability_rating   1.0      True
# 276     comment_lines_density   0.7     False
# 259  duplicated_lines_density   0.0      True
# 260                 functions    53       NaN
# 261           security_rating   1.0      True
# 262                     files    16       NaN
# 263                complexity    68       NaN
# 264                     ncloc   560       NaN
# 265                  coverage  87.6     False
# 266        reliability_rating   1.0      True
# 267     comment_lines_density   0.7     False
# 0    duplicated_lines_density   0.0      True
# 1                   functions    23       NaN
# 2             security_rating   1.0      True
# 3                       files    21       NaN
# 4                  complexity    23       NaN
# 5                       ncloc   162       NaN
# 6          reliability_rating   1.0      True
# 7       comment_lines_density   0.0     False
# 8    duplicated_lines_density   0.0      True
# 9                   functions    20       NaN
# 10            security_rating   1.0      True
# 11                      files     8       NaN
# 12                 complexity    22       NaN
# 13                      ncloc   148       NaN
# 14                   coverage  96.1     False
# 15         reliability_rating   1.0      True
# 16      comment_lines_density   0.7     False
# 17   duplicated_lines_density   0.0      True
# 18                  functions    20       NaN
# 19            security_rating   1.0      True
# 20                      files     8       NaN
# 21                 complexity    22       NaN
# 22                      ncloc   151       NaN
# 23                   coverage  96.1     False
# 24         reliability_rating   1.0      True
# 25      comment_lines_density   0.7     False
# 26   duplicated_lines_density   0.0      True
# 27                  functions    61       NaN
# 28            security_rating   1.0      True
# 29                      files    23       NaN
# 30                 complexity    66       NaN
# 31                      ncloc   601       NaN
# 32         reliability_rating   1.0      True
# 33      comment_lines_density   0.8     False
# 34   duplicated_lines_density   0.0      True
# 35            security_rating   1.0      True
# 36                   coverage  90.8     False
# 37         reliability_rating   1.0      True
# 367  duplicated_lines_density   0.0      True
# 368                 functions   165       NaN
# 369           security_rating   1.0      True
# 370                     files    33       NaN
# 371                complexity   245       NaN
# 372                     ncloc  1921       NaN
# 373                  coverage   0.0     False
# 374        reliability_rating   1.0      True
# 375     comment_lines_density   1.1     False
# 394  duplicated_lines_density   0.0      True
# 395                 functions   113       NaN
# 396           security_rating   1.0      True
# 397                     files    55       NaN
# 398                complexity   177       NaN
# 399                     ncloc  1412       NaN
# 400                  coverage   0.0     False
# 401        reliability_rating   3.0     False
# 402     comment_lines_density   3.4     False
# 385  duplicated_lines_density   0.0      True
# 386                 functions   113       NaN
# 387           security_rating   1.0      True
# 388                     files    55       NaN
# 389                complexity   177       NaN
# 390                     ncloc  1412       NaN
# 391                  coverage   0.0     False
# 392        reliability_rating   3.0     False
# 393     comment_lines_density   3.4     False
# 349  duplicated_lines_density   0.0      True
# 350                 functions    43       NaN
# 351           security_rating   1.0      True
# 352                     files    10       NaN
# 353                complexity    62       NaN
# 354                     ncloc   525       NaN
# 355                  coverage   0.0     False
# 356        reliability_rating   1.0      True
# 357     comment_lines_density   2.2     False
# 295  duplicated_lines_density   0.0      True
# 296                 functions    43       NaN
# 297           security_rating   1.0      True
# 298                     files    10       NaN
# 299                complexity    62       NaN
# 300                     ncloc   525       NaN
# 301                  coverage   0.0     False
# 302        reliability_rating   1.0      True
# 303     comment_lines_density   2.2     False
# 358  duplicated_lines_density   3.4     False
# 359                 functions    88       NaN
# 360           security_rating   1.0      True
# 361                     files    18       NaN
# 362                complexity   129       NaN
# 363                     ncloc   975       NaN
# 364                  coverage   0.0     False
# 365        reliability_rating   1.0      True
# 366     comment_lines_density   1.2     False
# 277  duplicated_lines_density   3.4     False
# 278                 functions   100       NaN
# 279           security_rating   1.0      True
# 280                     files    20       NaN
# 281                complexity   144       NaN
# 282                     ncloc  1077       NaN
# 283                  coverage   0.0     False
# 284        reliability_rating   1.0      True
# 285     comment_lines_density   1.5     False
# 304  duplicated_lines_density   0.0      True
# 305                 functions   144       NaN
# 306           security_rating   1.0      True
# 307                     files    27       NaN
# 308                complexity   217       NaN
# 309                     ncloc  1625       NaN
# 310                  coverage   0.0     False
# 311        reliability_rating   1.0      True
# 312     comment_lines_density   1.2     False
# 376  duplicated_lines_density   0.0      True
# 377                 functions   157       NaN
# 378           security_rating   1.0      True
# 379                     files    30       NaN
# 380                complexity   235       NaN
# 381                     ncloc  1788       NaN
# 382                  coverage   0.0     False
# 383        reliability_rating   1.0      True
# 384     comment_lines_density   1.2     False
# 313  duplicated_lines_density   1.4     False
# 314                 functions   174       NaN
# 315           security_rating   1.0      True
# 316                     files    35       NaN
# 317                complexity   256       NaN
# 318                     ncloc  2086       NaN
# 319                  coverage   0.0     False
# 320        reliability_rating   1.0      True
# 321     comment_lines_density   1.0     False
# 331  duplicated_lines_density   1.4     False
# 332                 functions   178       NaN
# 333           security_rating   1.0      True
# 334                     files    36       NaN
# 335                complexity   264       NaN
# 336                     ncloc  2136       NaN
# 337                  coverage   0.0     False
# 338        reliability_rating   1.0      True
# 339     comment_lines_density   1.0     False
# 286  duplicated_lines_density   2.6     False
# 287                 functions   263       NaN
# 288           security_rating   1.0      True
# 289                     files    52       NaN
# 290                complexity   389       NaN
# 291                     ncloc  3091       NaN
# 292                  coverage   0.0     False
# 293        reliability_rating   1.0      True
# 294     comment_lines_density   1.3     False
# 340  duplicated_lines_density   2.3     False
# 341                 functions   297       NaN
# 342           security_rating   1.0      True
# 343                     files    56       NaN
# 344                complexity   447       NaN
# 345                     ncloc  3545       NaN
# 346                  coverage   0.0     False
# 347        reliability_rating   1.0      True
# 348     comment_lines_density   1.3     False
# 322  duplicated_lines_density   2.3     False
# 323                 functions   295       NaN
# 324           security_rating   1.0      True
# 325                     files    56       NaN
# 326                complexity   445       NaN
# 327                     ncloc  3511       NaN
# 328                  coverage   0.0     False
# 329        reliability_rating   1.0      True
# 330     comment_lines_density   1.3     False
#
#                                               filename  \
# 92   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 93   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 94   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 95   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 96   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 97   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 98   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 99   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 47   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 48   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 49   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 50   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 51   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 52   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 53   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 54   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 55   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 74   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 75   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 76   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 77   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 78   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 79   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 80   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 81   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 82   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 100  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 101  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 102  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 103  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 104  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 105  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 106  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 107  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 108  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 65   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 66   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 67   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 68   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 69   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 70   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 71   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 72   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 73   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 38   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 39   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 40   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 41   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 42   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 43   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 44   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 45   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 46   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 109  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 110  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 111  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 112  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 113  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 114  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 115  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 116  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 117  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 83   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 84   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 85   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 86   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 87   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 88   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 89   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 90   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 91   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 56   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 57   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 58   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 59   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 60   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 61   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 62   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 63   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 64   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 198  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 199  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 200  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 201  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 202  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 203  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 204  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 205  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 136  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 137  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 138  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 139  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 140  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 141  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 142  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 143  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 144  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 163  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 164  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 165  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 166  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 167  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 168  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 169  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 170  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 154  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 155  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 156  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 157  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 158  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 159  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 160  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 161  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 162  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 180  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 181  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 182  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 183  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 184  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 185  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 186  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 187  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 188  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 127  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 128  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 129  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 130  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 131  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 132  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 133  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 134  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 135  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 118  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 119  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 120  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 121  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 122  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 123  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 124  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 125  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 126  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 206  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 207  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 208  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 209  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 210  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 211  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 212  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 213  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 214  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 189  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 190  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 191  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 192  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 193  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 194  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 195  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 196  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 197  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 145  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 146  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 147  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 148  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 149  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 150  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 151  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 152  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 153  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 215  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 216  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 217  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 218  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 219  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 220  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 221  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 222  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 223  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 224  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 225  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 226  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 227  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 228  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 229  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 230  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 231  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 232  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 171  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 172  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 173  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 174  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 175  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 176  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 177  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 178  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 179  fga-eps-mds-2021_1-Cartografia-social-api-gate...
# 242  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 243  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 244  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 245  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 246  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 247  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 248  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 249  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 250  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 251  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 252  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 253  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 254  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 255  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 256  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 257  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 258  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 233  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 234  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 235  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 236  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 237  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 238  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 239  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 240  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 241  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 268  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 269  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 270  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 271  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 272  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 273  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 274  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 275  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 276  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 259  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 260  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 261  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 262  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 263  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 264  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 265  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 266  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 267  fga-eps-mds-2021_1-Cartografia-social-api-mapa...
# 0    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 1    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 2    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 3    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 4    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 5    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 6    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 7    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 8    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 9    fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 10   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 11   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 12   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 13   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 14   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 15   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 16   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 17   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 18   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 19   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 20   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 21   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 22   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 23   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 24   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 25   fga-eps-mds-2021_1-Cartografia-social-api-midi...
# 26   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 27   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 28   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 29   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 30   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 31   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 32   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 33   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 34   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 35   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 36   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 37   fga-eps-mds-2021_1-Cartografia-social-api-user...
# 367  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 368  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 369  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 370  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 371  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 372  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 373  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 374  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 375  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 394  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 395  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 396  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 397  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 398  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 399  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 400  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 401  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 402  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 385  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 386  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 387  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 388  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 389  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 390  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 391  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 392  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 393  fga-eps-mds-2021_1-Cartografia-social-front_09...
# 349  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 350  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 351  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 352  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 353  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 354  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 355  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 356  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 357  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 295  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 296  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 297  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 298  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 299  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 300  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 301  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 302  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 303  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 358  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 359  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 360  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 361  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 362  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 363  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 364  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 365  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 366  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 277  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 278  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 279  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 280  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 281  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 282  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 283  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 284  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 285  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 304  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 305  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 306  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 307  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 308  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 309  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 310  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 311  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 312  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 376  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 377  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 378  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 379  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 380  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 381  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 382  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 383  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 384  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 313  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 314  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 315  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 316  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 317  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 318  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 319  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 320  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 321  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 331  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 332  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 333  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 334  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 335  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 336  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 337  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 338  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 339  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 286  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 287  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 288  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 289  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 290  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 291  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 292  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 293  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 294  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 340  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 341  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 342  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 343  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 344  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 345  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 346  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 347  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 348  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 322  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 323  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 324  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 325  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 326  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 327  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 328  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 329  fga-eps-mds-2021_1-Cartografia-social-front_10...
# 330  fga-eps-mds-2021_1-Cartografia-social-front_10...
#
#                              repository  version
# 92   Cartografia-social-api-comunidades   v0.0.1
# 93   Cartografia-social-api-comunidades   v0.0.1
# 94   Cartografia-social-api-comunidades   v0.0.1
# 95   Cartografia-social-api-comunidades   v0.0.1
# 96   Cartografia-social-api-comunidades   v0.0.1
# 97   Cartografia-social-api-comunidades   v0.0.1
# 98   Cartografia-social-api-comunidades   v0.0.1
# 99   Cartografia-social-api-comunidades   v0.0.1
# 47   Cartografia-social-api-comunidades   v0.0.2
# 48   Cartografia-social-api-comunidades   v0.0.2
# 49   Cartografia-social-api-comunidades   v0.0.2
# 50   Cartografia-social-api-comunidades   v0.0.2
# 51   Cartografia-social-api-comunidades   v0.0.2
# 52   Cartografia-social-api-comunidades   v0.0.2
# 53   Cartografia-social-api-comunidades   v0.0.2
# 54   Cartografia-social-api-comunidades   v0.0.2
# 55   Cartografia-social-api-comunidades   v0.0.2
# 74   Cartografia-social-api-comunidades   v0.0.3
# 75   Cartografia-social-api-comunidades   v0.0.3
# 76   Cartografia-social-api-comunidades   v0.0.3
# 77   Cartografia-social-api-comunidades   v0.0.3
# 78   Cartografia-social-api-comunidades   v0.0.3
# 79   Cartografia-social-api-comunidades   v0.0.3
# 80   Cartografia-social-api-comunidades   v0.0.3
# 81   Cartografia-social-api-comunidades   v0.0.3
# 82   Cartografia-social-api-comunidades   v0.0.3
# 100  Cartografia-social-api-comunidades   v0.0.4
# 101  Cartografia-social-api-comunidades   v0.0.4
# 102  Cartografia-social-api-comunidades   v0.0.4
# 103  Cartografia-social-api-comunidades   v0.0.4
# 104  Cartografia-social-api-comunidades   v0.0.4
# 105  Cartografia-social-api-comunidades   v0.0.4
# 106  Cartografia-social-api-comunidades   v0.0.4
# 107  Cartografia-social-api-comunidades   v0.0.4
# 108  Cartografia-social-api-comunidades   v0.0.4
# 65   Cartografia-social-api-comunidades   v0.0.5
# 66   Cartografia-social-api-comunidades   v0.0.5
# 67   Cartografia-social-api-comunidades   v0.0.5
# 68   Cartografia-social-api-comunidades   v0.0.5
# 69   Cartografia-social-api-comunidades   v0.0.5
# 70   Cartografia-social-api-comunidades   v0.0.5
# 71   Cartografia-social-api-comunidades   v0.0.5
# 72   Cartografia-social-api-comunidades   v0.0.5
# 73   Cartografia-social-api-comunidades   v0.0.5
# 38   Cartografia-social-api-comunidades   v0.0.6
# 39   Cartografia-social-api-comunidades   v0.0.6
# 40   Cartografia-social-api-comunidades   v0.0.6
# 41   Cartografia-social-api-comunidades   v0.0.6
# 42   Cartografia-social-api-comunidades   v0.0.6
# 43   Cartografia-social-api-comunidades   v0.0.6
# 44   Cartografia-social-api-comunidades   v0.0.6
# 45   Cartografia-social-api-comunidades   v0.0.6
# 46   Cartografia-social-api-comunidades   v0.0.6
# 109  Cartografia-social-api-comunidades   v0.0.7
# 110  Cartografia-social-api-comunidades   v0.0.7
# 111  Cartografia-social-api-comunidades   v0.0.7
# 112  Cartografia-social-api-comunidades   v0.0.7
# 113  Cartografia-social-api-comunidades   v0.0.7
# 114  Cartografia-social-api-comunidades   v0.0.7
# 115  Cartografia-social-api-comunidades   v0.0.7
# 116  Cartografia-social-api-comunidades   v0.0.7
# 117  Cartografia-social-api-comunidades   v0.0.7
# 83   Cartografia-social-api-comunidades   v0.0.8
# 84   Cartografia-social-api-comunidades   v0.0.8
# 85   Cartografia-social-api-comunidades   v0.0.8
# 86   Cartografia-social-api-comunidades   v0.0.8
# 87   Cartografia-social-api-comunidades   v0.0.8
# 88   Cartografia-social-api-comunidades   v0.0.8
# 89   Cartografia-social-api-comunidades   v0.0.8
# 90   Cartografia-social-api-comunidades   v0.0.8
# 91   Cartografia-social-api-comunidades   v0.0.8
# 56   Cartografia-social-api-comunidades   v0.0.9
# 57   Cartografia-social-api-comunidades   v0.0.9
# 58   Cartografia-social-api-comunidades   v0.0.9
# 59   Cartografia-social-api-comunidades   v0.0.9
# 60   Cartografia-social-api-comunidades   v0.0.9
# 61   Cartografia-social-api-comunidades   v0.0.9
# 62   Cartografia-social-api-comunidades   v0.0.9
# 63   Cartografia-social-api-comunidades   v0.0.9
# 64   Cartografia-social-api-comunidades   v0.0.9
# 198      Cartografia-social-api-gateway   v0.0.1
# 199      Cartografia-social-api-gateway   v0.0.1
# 200      Cartografia-social-api-gateway   v0.0.1
# 201      Cartografia-social-api-gateway   v0.0.1
# 202      Cartografia-social-api-gateway   v0.0.1
# 203      Cartografia-social-api-gateway   v0.0.1
# 204      Cartografia-social-api-gateway   v0.0.1
# 205      Cartografia-social-api-gateway   v0.0.1
# 136      Cartografia-social-api-gateway  v0.0.10
# 137      Cartografia-social-api-gateway  v0.0.10
# 138      Cartografia-social-api-gateway  v0.0.10
# 139      Cartografia-social-api-gateway  v0.0.10
# 140      Cartografia-social-api-gateway  v0.0.10
# 141      Cartografia-social-api-gateway  v0.0.10
# 142      Cartografia-social-api-gateway  v0.0.10
# 143      Cartografia-social-api-gateway  v0.0.10
# 144      Cartografia-social-api-gateway  v0.0.10
# 163      Cartografia-social-api-gateway   v0.0.2
# 164      Cartografia-social-api-gateway   v0.0.2
# 165      Cartografia-social-api-gateway   v0.0.2
# 166      Cartografia-social-api-gateway   v0.0.2
# 167      Cartografia-social-api-gateway   v0.0.2
# 168      Cartografia-social-api-gateway   v0.0.2
# 169      Cartografia-social-api-gateway   v0.0.2
# 170      Cartografia-social-api-gateway   v0.0.2
# 154      Cartografia-social-api-gateway   v0.0.3
# 155      Cartografia-social-api-gateway   v0.0.3
# 156      Cartografia-social-api-gateway   v0.0.3
# 157      Cartografia-social-api-gateway   v0.0.3
# 158      Cartografia-social-api-gateway   v0.0.3
# 159      Cartografia-social-api-gateway   v0.0.3
# 160      Cartografia-social-api-gateway   v0.0.3
# 161      Cartografia-social-api-gateway   v0.0.3
# 162      Cartografia-social-api-gateway   v0.0.3
# 180      Cartografia-social-api-gateway   v0.0.4
# 181      Cartografia-social-api-gateway   v0.0.4
# 182      Cartografia-social-api-gateway   v0.0.4
# 183      Cartografia-social-api-gateway   v0.0.4
# 184      Cartografia-social-api-gateway   v0.0.4
# 185      Cartografia-social-api-gateway   v0.0.4
# 186      Cartografia-social-api-gateway   v0.0.4
# 187      Cartografia-social-api-gateway   v0.0.4
# 188      Cartografia-social-api-gateway   v0.0.4
# 127      Cartografia-social-api-gateway   v0.0.5
# 128      Cartografia-social-api-gateway   v0.0.5
# 129      Cartografia-social-api-gateway   v0.0.5
# 130      Cartografia-social-api-gateway   v0.0.5
# 131      Cartografia-social-api-gateway   v0.0.5
# 132      Cartografia-social-api-gateway   v0.0.5
# 133      Cartografia-social-api-gateway   v0.0.5
# 134      Cartografia-social-api-gateway   v0.0.5
# 135      Cartografia-social-api-gateway   v0.0.5
# 118      Cartografia-social-api-gateway   v0.0.6
# 119      Cartografia-social-api-gateway   v0.0.6
# 120      Cartografia-social-api-gateway   v0.0.6
# 121      Cartografia-social-api-gateway   v0.0.6
# 122      Cartografia-social-api-gateway   v0.0.6
# 123      Cartografia-social-api-gateway   v0.0.6
# 124      Cartografia-social-api-gateway   v0.0.6
# 125      Cartografia-social-api-gateway   v0.0.6
# 126      Cartografia-social-api-gateway   v0.0.6
# 206      Cartografia-social-api-gateway   v0.0.7
# 207      Cartografia-social-api-gateway   v0.0.7
# 208      Cartografia-social-api-gateway   v0.0.7
# 209      Cartografia-social-api-gateway   v0.0.7
# 210      Cartografia-social-api-gateway   v0.0.7
# 211      Cartografia-social-api-gateway   v0.0.7
# 212      Cartografia-social-api-gateway   v0.0.7
# 213      Cartografia-social-api-gateway   v0.0.7
# 214      Cartografia-social-api-gateway   v0.0.7
# 189      Cartografia-social-api-gateway   v0.0.8
# 190      Cartografia-social-api-gateway   v0.0.8
# 191      Cartografia-social-api-gateway   v0.0.8
# 192      Cartografia-social-api-gateway   v0.0.8
# 193      Cartografia-social-api-gateway   v0.0.8
# 194      Cartografia-social-api-gateway   v0.0.8
# 195      Cartografia-social-api-gateway   v0.0.8
# 196      Cartografia-social-api-gateway   v0.0.8
# 197      Cartografia-social-api-gateway   v0.0.8
# 145      Cartografia-social-api-gateway   v0.0.9
# 146      Cartografia-social-api-gateway   v0.0.9
# 147      Cartografia-social-api-gateway   v0.0.9
# 148      Cartografia-social-api-gateway   v0.0.9
# 149      Cartografia-social-api-gateway   v0.0.9
# 150      Cartografia-social-api-gateway   v0.0.9
# 151      Cartografia-social-api-gateway   v0.0.9
# 152      Cartografia-social-api-gateway   v0.0.9
# 153      Cartografia-social-api-gateway   v0.0.9
# 215      Cartografia-social-api-gateway   v1.0.0
# 216      Cartografia-social-api-gateway   v1.0.0
# 217      Cartografia-social-api-gateway   v1.0.0
# 218      Cartografia-social-api-gateway   v1.0.0
# 219      Cartografia-social-api-gateway   v1.0.0
# 220      Cartografia-social-api-gateway   v1.0.0
# 221      Cartografia-social-api-gateway   v1.0.0
# 222      Cartografia-social-api-gateway   v1.0.0
# 223      Cartografia-social-api-gateway   v1.0.0
# 224      Cartografia-social-api-gateway   v1.0.1
# 225      Cartografia-social-api-gateway   v1.0.1
# 226      Cartografia-social-api-gateway   v1.0.1
# 227      Cartografia-social-api-gateway   v1.0.1
# 228      Cartografia-social-api-gateway   v1.0.1
# 229      Cartografia-social-api-gateway   v1.0.1
# 230      Cartografia-social-api-gateway   v1.0.1
# 231      Cartografia-social-api-gateway   v1.0.1
# 232      Cartografia-social-api-gateway   v1.0.1
# 171      Cartografia-social-api-gateway   v1.0.2
# 172      Cartografia-social-api-gateway   v1.0.2
# 173      Cartografia-social-api-gateway   v1.0.2
# 174      Cartografia-social-api-gateway   v1.0.2
# 175      Cartografia-social-api-gateway   v1.0.2
# 176      Cartografia-social-api-gateway   v1.0.2
# 177      Cartografia-social-api-gateway   v1.0.2
# 178      Cartografia-social-api-gateway   v1.0.2
# 179      Cartografia-social-api-gateway   v1.0.2
# 242        Cartografia-social-api-mapas   v0.0.1
# 243        Cartografia-social-api-mapas   v0.0.1
# 244        Cartografia-social-api-mapas   v0.0.1
# 245        Cartografia-social-api-mapas   v0.0.1
# 246        Cartografia-social-api-mapas   v0.0.1
# 247        Cartografia-social-api-mapas   v0.0.1
# 248        Cartografia-social-api-mapas   v0.0.1
# 249        Cartografia-social-api-mapas   v0.0.1
# 250        Cartografia-social-api-mapas   v0.0.2
# 251        Cartografia-social-api-mapas   v0.0.2
# 252        Cartografia-social-api-mapas   v0.0.2
# 253        Cartografia-social-api-mapas   v0.0.2
# 254        Cartografia-social-api-mapas   v0.0.2
# 255        Cartografia-social-api-mapas   v0.0.2
# 256        Cartografia-social-api-mapas   v0.0.2
# 257        Cartografia-social-api-mapas   v0.0.2
# 258        Cartografia-social-api-mapas   v0.0.2
# 233        Cartografia-social-api-mapas   v1.0.0
# 234        Cartografia-social-api-mapas   v1.0.0
# 235        Cartografia-social-api-mapas   v1.0.0
# 236        Cartografia-social-api-mapas   v1.0.0
# 237        Cartografia-social-api-mapas   v1.0.0
# 238        Cartografia-social-api-mapas   v1.0.0
# 239        Cartografia-social-api-mapas   v1.0.0
# 240        Cartografia-social-api-mapas   v1.0.0
# 241        Cartografia-social-api-mapas   v1.0.0
# 268        Cartografia-social-api-mapas   v1.0.1
# 269        Cartografia-social-api-mapas   v1.0.1
# 270        Cartografia-social-api-mapas   v1.0.1
# 271        Cartografia-social-api-mapas   v1.0.1
# 272        Cartografia-social-api-mapas   v1.0.1
# 273        Cartografia-social-api-mapas   v1.0.1
# 274        Cartografia-social-api-mapas   v1.0.1
# 275        Cartografia-social-api-mapas   v1.0.1
# 276        Cartografia-social-api-mapas   v1.0.1
# 259        Cartografia-social-api-mapas   v1.0.2
# 260        Cartografia-social-api-mapas   v1.0.2
# 261        Cartografia-social-api-mapas   v1.0.2
# 262        Cartografia-social-api-mapas   v1.0.2
# 263        Cartografia-social-api-mapas   v1.0.2
# 264        Cartografia-social-api-mapas   v1.0.2
# 265        Cartografia-social-api-mapas   v1.0.2
# 266        Cartografia-social-api-mapas   v1.0.2
# 267        Cartografia-social-api-mapas   v1.0.2
# 0          Cartografia-social-api-midia   v0.0.1
# 1          Cartografia-social-api-midia   v0.0.1
# 2          Cartografia-social-api-midia   v0.0.1
# 3          Cartografia-social-api-midia   v0.0.1
# 4          Cartografia-social-api-midia   v0.0.1
# 5          Cartografia-social-api-midia   v0.0.1
# 6          Cartografia-social-api-midia   v0.0.1
# 7          Cartografia-social-api-midia   v0.0.1
# 8          Cartografia-social-api-midia   v1.0.0
# 9          Cartografia-social-api-midia   v1.0.0
# 10         Cartografia-social-api-midia   v1.0.0
# 11         Cartografia-social-api-midia   v1.0.0
# 12         Cartografia-social-api-midia   v1.0.0
# 13         Cartografia-social-api-midia   v1.0.0
# 14         Cartografia-social-api-midia   v1.0.0
# 15         Cartografia-social-api-midia   v1.0.0
# 16         Cartografia-social-api-midia   v1.0.0
# 17         Cartografia-social-api-midia   v1.0.1
# 18         Cartografia-social-api-midia   v1.0.1
# 19         Cartografia-social-api-midia   v1.0.1
# 20         Cartografia-social-api-midia   v1.0.1
# 21         Cartografia-social-api-midia   v1.0.1
# 22         Cartografia-social-api-midia   v1.0.1
# 23         Cartografia-social-api-midia   v1.0.1
# 24         Cartografia-social-api-midia   v1.0.1
# 25         Cartografia-social-api-midia   v1.0.1
# 26         Cartografia-social-api-users   v0.0.1
# 27         Cartografia-social-api-users   v0.0.1
# 28         Cartografia-social-api-users   v0.0.1
# 29         Cartografia-social-api-users   v0.0.1
# 30         Cartografia-social-api-users   v0.0.1
# 31         Cartografia-social-api-users   v0.0.1
# 32         Cartografia-social-api-users   v0.0.1
# 33         Cartografia-social-api-users   v0.0.1
# 34         Cartografia-social-api-users   v1.0.0
# 35         Cartografia-social-api-users   v1.0.0
# 36         Cartografia-social-api-users   v1.0.0
# 37         Cartografia-social-api-users   v1.0.0
# 367            Cartografia-social-front      MVP
# 368            Cartografia-social-front      MVP
# 369            Cartografia-social-front      MVP
# 370            Cartografia-social-front      MVP
# 371            Cartografia-social-front      MVP
# 372            Cartografia-social-front      MVP
# 373            Cartografia-social-front      MVP
# 374            Cartografia-social-front      MVP
# 375            Cartografia-social-front      MVP
# 394            Cartografia-social-front   v0.0.1
# 395            Cartografia-social-front   v0.0.1
# 396            Cartografia-social-front   v0.0.1
# 397            Cartografia-social-front   v0.0.1
# 398            Cartografia-social-front   v0.0.1
# 399            Cartografia-social-front   v0.0.1
# 400            Cartografia-social-front   v0.0.1
# 401            Cartografia-social-front   v0.0.1
# 402            Cartografia-social-front   v0.0.1
# 385            Cartografia-social-front   v0.0.2
# 386            Cartografia-social-front   v0.0.2
# 387            Cartografia-social-front   v0.0.2
# 388            Cartografia-social-front   v0.0.2
# 389            Cartografia-social-front   v0.0.2
# 390            Cartografia-social-front   v0.0.2
# 391            Cartografia-social-front   v0.0.2
# 392            Cartografia-social-front   v0.0.2
# 393            Cartografia-social-front   v0.0.2
# 349            Cartografia-social-front   v0.0.3
# 350            Cartografia-social-front   v0.0.3
# 351            Cartografia-social-front   v0.0.3
# 352            Cartografia-social-front   v0.0.3
# 353            Cartografia-social-front   v0.0.3
# 354            Cartografia-social-front   v0.0.3
# 355            Cartografia-social-front   v0.0.3
# 356            Cartografia-social-front   v0.0.3
# 357            Cartografia-social-front   v0.0.3
# 295            Cartografia-social-front   v0.0.4
# 296            Cartografia-social-front   v0.0.4
# 297            Cartografia-social-front   v0.0.4
# 298            Cartografia-social-front   v0.0.4
# 299            Cartografia-social-front   v0.0.4
# 300            Cartografia-social-front   v0.0.4
# 301            Cartografia-social-front   v0.0.4
# 302            Cartografia-social-front   v0.0.4
# 303            Cartografia-social-front   v0.0.4
# 358            Cartografia-social-front   v0.0.5
# 359            Cartografia-social-front   v0.0.5
# 360            Cartografia-social-front   v0.0.5
# 361            Cartografia-social-front   v0.0.5
# 362            Cartografia-social-front   v0.0.5
# 363            Cartografia-social-front   v0.0.5
# 364            Cartografia-social-front   v0.0.5
# 365            Cartografia-social-front   v0.0.5
# 366            Cartografia-social-front   v0.0.5
# 277            Cartografia-social-front   v0.0.6
# 278            Cartografia-social-front   v0.0.6
# 279            Cartografia-social-front   v0.0.6
# 280            Cartografia-social-front   v0.0.6
# 281            Cartografia-social-front   v0.0.6
# 282            Cartografia-social-front   v0.0.6
# 283            Cartografia-social-front   v0.0.6
# 284            Cartografia-social-front   v0.0.6
# 285            Cartografia-social-front   v0.0.6
# 304            Cartografia-social-front   v0.0.8
# 305            Cartografia-social-front   v0.0.8
# 306            Cartografia-social-front   v0.0.8
# 307            Cartografia-social-front   v0.0.8
# 308            Cartografia-social-front   v0.0.8
# 309            Cartografia-social-front   v0.0.8
# 310            Cartografia-social-front   v0.0.8
# 311            Cartografia-social-front   v0.0.8
# 312            Cartografia-social-front   v0.0.8
# 376            Cartografia-social-front   v0.0.9
# 377            Cartografia-social-front   v0.0.9
# 378            Cartografia-social-front   v0.0.9
# 379            Cartografia-social-front   v0.0.9
# 380            Cartografia-social-front   v0.0.9
# 381            Cartografia-social-front   v0.0.9
# 382            Cartografia-social-front   v0.0.9
# 383            Cartografia-social-front   v0.0.9
# 384            Cartografia-social-front   v0.0.9
# 313            Cartografia-social-front   v1.0.0
# 314            Cartografia-social-front   v1.0.0
# 315            Cartografia-social-front   v1.0.0
# 316            Cartografia-social-front   v1.0.0
# 317            Cartografia-social-front   v1.0.0
# 318            Cartografia-social-front   v1.0.0
# 319            Cartografia-social-front   v1.0.0
# 320            Cartografia-social-front   v1.0.0
# 321            Cartografia-social-front   v1.0.0
# 331            Cartografia-social-front   v1.0.1
# 332            Cartografia-social-front   v1.0.1
# 333            Cartografia-social-front   v1.0.1
# 334            Cartografia-social-front   v1.0.1
# 335            Cartografia-social-front   v1.0.1
# 336            Cartografia-social-front   v1.0.1
# 337            Cartografia-social-front   v1.0.1
# 338            Cartografia-social-front   v1.0.1
# 339            Cartografia-social-front   v1.0.1
# 286            Cartografia-social-front   v1.1.0
# 287            Cartografia-social-front   v1.1.0
# 288            Cartografia-social-front   v1.1.0
# 289            Cartografia-social-front   v1.1.0
# 290            Cartografia-social-front   v1.1.0
# 291            Cartografia-social-front   v1.1.0
# 292            Cartografia-social-front   v1.1.0
# 293            Cartografia-social-front   v1.1.0
# 294            Cartografia-social-front   v1.1.0
# 340            Cartografia-social-front   v1.1.1
# 341            Cartografia-social-front   v1.1.1
# 342            Cartografia-social-front   v1.1.1
# 343            Cartografia-social-front   v1.1.1
# 344            Cartografia-social-front   v1.1.1
# 345            Cartografia-social-front   v1.1.1
# 346            Cartografia-social-front   v1.1.1
# 347            Cartografia-social-front   v1.1.1
# 348            Cartografia-social-front   v1.1.1
# 322            Cartografia-social-front   v1.1.2
# 323            Cartografia-social-front   v1.1.2
# 324            Cartografia-social-front   v1.1.2
# 325            Cartografia-social-front   v1.1.2
# 326            Cartografia-social-front   v1.1.2
# 327            Cartografia-social-front   v1.1.2
# 328            Cartografia-social-front   v1.1.2
# 329            Cartografia-social-front   v1.1.2
# 330            Cartografia-social-front   v1.1.2

# %%
base_component_df.head(50)
# Out:
#                        metric value bestValue  \
# 92   duplicated_lines_density   0.0      True
# 93                  functions    35       NaN
# 94            security_rating   1.0      True
# 95                      files    30       NaN
# 96                 complexity    35       NaN
# 97                      ncloc   336       NaN
# 98         reliability_rating   1.0      True
# 99      comment_lines_density   0.0     False
# 47   duplicated_lines_density   0.0      True
# 48                  functions    16       NaN
# 49            security_rating   1.0      True
# 50                      files     8       NaN
# 51                 complexity    20       NaN
# 52                      ncloc   161       NaN
# 53                   coverage  68.0     False
# 54         reliability_rating   1.0      True
# 55      comment_lines_density   0.0     False
# 74   duplicated_lines_density   0.0      True
# 75                  functions    16       NaN
# 76            security_rating   1.0      True
# 77                      files     8       NaN
# 78                 complexity    20       NaN
# 79                      ncloc   161       NaN
# 80                   coverage  83.8     False
# 81         reliability_rating   1.0      True
# 82      comment_lines_density   0.0     False
# 100  duplicated_lines_density   0.0      True
# 101                 functions    21       NaN
# 102           security_rating   1.0      True
# 103                     files    10       NaN
# 104                complexity    25       NaN
# 105                     ncloc   196       NaN
# 106                  coverage  84.4     False
# 107        reliability_rating   1.0      True
# 108     comment_lines_density   0.0     False
# 65   duplicated_lines_density   0.0      True
# 66                  functions    31       NaN
# 67            security_rating   1.0      True
# 68                      files    12       NaN
# 69                 complexity    36       NaN
# 70                      ncloc   284       NaN
# 71                   coverage  85.9     False
# 72         reliability_rating   1.0      True
# 73      comment_lines_density   0.7     False
# 38   duplicated_lines_density   0.0      True
# 39                  functions    39       NaN
# 40            security_rating   1.0      True
# 41                      files    12       NaN
# 42                 complexity    45       NaN
# 43                      ncloc   334       NaN
#
#                                               filename  \
# 92   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 93   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 94   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 95   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 96   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 97   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 98   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 99   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 47   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 48   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 49   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 50   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 51   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 52   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 53   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 54   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 55   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 74   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 75   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 76   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 77   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 78   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 79   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 80   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 81   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 82   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 100  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 101  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 102  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 103  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 104  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 105  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 106  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 107  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 108  fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 65   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 66   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 67   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 68   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 69   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 70   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 71   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 72   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 73   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 38   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 39   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 40   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 41   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 42   fga-eps-mds-2021_1-Cartografia-social-api-comu...
# 43   fga-eps-mds-2021_1-Cartografia-social-api-comu...
#
#                              repository version
# 92   Cartografia-social-api-comunidades  v0.0.1
# 93   Cartografia-social-api-comunidades  v0.0.1
# 94   Cartografia-social-api-comunidades  v0.0.1
# 95   Cartografia-social-api-comunidades  v0.0.1
# 96   Cartografia-social-api-comunidades  v0.0.1
# 97   Cartografia-social-api-comunidades  v0.0.1
# 98   Cartografia-social-api-comunidades  v0.0.1
# 99   Cartografia-social-api-comunidades  v0.0.1
# 47   Cartografia-social-api-comunidades  v0.0.2
# 48   Cartografia-social-api-comunidades  v0.0.2
# 49   Cartografia-social-api-comunidades  v0.0.2
# 50   Cartografia-social-api-comunidades  v0.0.2
# 51   Cartografia-social-api-comunidades  v0.0.2
# 52   Cartografia-social-api-comunidades  v0.0.2
# 53   Cartografia-social-api-comunidades  v0.0.2
# 54   Cartografia-social-api-comunidades  v0.0.2
# 55   Cartografia-social-api-comunidades  v0.0.2
# 74   Cartografia-social-api-comunidades  v0.0.3
# 75   Cartografia-social-api-comunidades  v0.0.3
# 76   Cartografia-social-api-comunidades  v0.0.3
# 77   Cartografia-social-api-comunidades  v0.0.3
# 78   Cartografia-social-api-comunidades  v0.0.3
# 79   Cartografia-social-api-comunidades  v0.0.3
# 80   Cartografia-social-api-comunidades  v0.0.3
# 81   Cartografia-social-api-comunidades  v0.0.3
# 82   Cartografia-social-api-comunidades  v0.0.3
# 100  Cartografia-social-api-comunidades  v0.0.4
# 101  Cartografia-social-api-comunidades  v0.0.4
# 102  Cartografia-social-api-comunidades  v0.0.4
# 103  Cartografia-social-api-comunidades  v0.0.4
# 104  Cartografia-social-api-comunidades  v0.0.4
# 105  Cartografia-social-api-comunidades  v0.0.4
# 106  Cartografia-social-api-comunidades  v0.0.4
# 107  Cartografia-social-api-comunidades  v0.0.4
# 108  Cartografia-social-api-comunidades  v0.0.4
# 65   Cartografia-social-api-comunidades  v0.0.5
# 66   Cartografia-social-api-comunidades  v0.0.5
# 67   Cartografia-social-api-comunidades  v0.0.5
# 68   Cartografia-social-api-comunidades  v0.0.5
# 69   Cartografia-social-api-comunidades  v0.0.5
# 70   Cartografia-social-api-comunidades  v0.0.5
# 71   Cartografia-social-api-comunidades  v0.0.5
# 72   Cartografia-social-api-comunidades  v0.0.5
# 73   Cartografia-social-api-comunidades  v0.0.5
# 38   Cartografia-social-api-comunidades  v0.0.6
# 39   Cartografia-social-api-comunidades  v0.0.6
# 40   Cartografia-social-api-comunidades  v0.0.6
# 41   Cartografia-social-api-comunidades  v0.0.6
# 42   Cartografia-social-api-comunidades  v0.0.6
# 43   Cartografia-social-api-comunidades  v0.0.6

# %% [markdown]
# #### Create dataframe per file

# %%
metric_list = ['files',
               'functions',
               'complexity',
               'comment_lines_density',
               'duplicated_lines_density',
               'coverage',
               'ncloc',
               'security_rating',
               'tests',
               'test_success_density',
               'test_execution_time',
               'reliability_rating']

len(metric_list)
# Out:
# 12

# %%
def metric_per_file(json):
    
    file_json = []
    
    for component in json['components']:
        if component['qualifier'] == 'FIL':
            file_json.append(component)
            
    return file_json

def generate_file_dataframe_per_release(metric_list, json, language_extension):
    
    df_columns = metric_list
    df = pd.DataFrame(columns = df_columns)
    
    for file in json:
        try:
            if file['language'] == language_extension:
                for measure in file['measures']:
                    df.at[file['path'], measure['metric']] = measure['value']
        except:
            pass
        
    df.reset_index(inplace = True)
    df = df.rename({'index': 'path'}, axis=1).drop(['files'], axis=1)

    return df

def create_file_df(json_list):
    
    df = pd.DataFrame()

    for i in json_list:

        file_component = read_json(i)
        
        file_component_data = metric_per_file(file_component)

        file_component_df = generate_file_dataframe_per_release(metric_list, file_component_data, language_extension = 'ts')

        file_component_df['filename'] = os.path.basename(i)

        df = df.append(file_component_df, ignore_index=True)
        
    # replace TeamName by yours.    
    aux_df = df['filename'].str.split(r"fga-eps-mds-2021_1-(.*?)_(.*?)_(.*?).json", expand=True)
    
    df['repository'] = aux_df[1]
    
    df['version'] = aux_df[3]
    
    df = df.sort_values(by=['repository', 'version'])

    df.to_csv('result2.csv')
    
    return df

# %%
file_component_df = create_file_df(jsons)

# %%
#print(file_component_df['version'])
file_component_df = file_component_df.sort_values(by='version')
#print(file_component_df)

# %%
#file_component_df.head(100)
file_component_df.repository.unique()
# Out:
# array(['Cartografia-social-api-comunidades',
#        'Cartografia-social-api-mapas', 'Cartografia-social-api-users',
#        'Cartografia-social-api-gateway', 'Cartografia-social-api-midia'],
#       dtype=object)

# %% [markdown]
# #### Create dataframe per repository

# %%
repository_dataframes = {} 

for repository in repos:
    df = file_component_df[file_component_df['repository'] == f"{repository}"]
    df.name = f"{repository}"
    repository_dataframes[f"{repository}"] = df
    
repository_dataframes.keys()
# Out:
# dict_keys(['2021.1-Cartografia-social-api-comunidades', '2021.1-Cartografia-social-api-gateway', '2021.1-Cartografia-social-api-mapas', '2021.1-Cartografia-social-api-midia', '2021.1-Cartografia-social-api-users', '2021.1-Cartografia-social-front'])

# %%
api_comunidades_df = file_component_df[file_component_df['repository'] == 'Cartografia-social-api-comunidades']
api_gateway_df = file_component_df[file_component_df['repository'] == 'Cartografia-social-api-gateway']
api_mapas_df = file_component_df[file_component_df['repository'] == 'Cartografia-social-api-mapas']
api_midia_df = file_component_df[file_component_df['repository'] == 'Cartografia-social-api-midia']
api_users_df = file_component_df[file_component_df['repository'] == 'Cartografia-social-api-users']
#front_df = file_component_df[file_component_df['repository'] == '2021.1-Cartografia-social-api-front']
#print(api_comunidades_df)

# %% [markdown]
# ### Measure calculations according Q-Rapids quality model

# %% [markdown]
# # Quality Aspect - Maintainability
# ## Factor - Code Quality

# %% [markdown]
# ##### COMPLEXITY

# %%
def m1(df):
    
    density_non_complex_files = len(df[(df['complexity'].astype(float)/df['functions'].astype(float)) < 10])/len(df)
    
    return density_non_complex_files

# %% [markdown]
# ##### COMMENTS

# %%
def m2(df):
    
    density_comment_files = len(df[(df['comment_lines_density'].astype(float) > 10) & (df['comment_lines_density'].astype(float) < 30)])/len(df)
    
    return density_comment_files

# %% [markdown]
# ##### DUPLICATIONS

# %%
def m3(df):
    
    duplication = len(df[(df['duplicated_lines_density'].astype(float) < 5)])/len(df)
    
    return duplication

# %%
def _ncloc(df):
    ncloc = 0
    for each in df['ncloc']:
        ncloc += int(each)
    
    return ncloc

# %% [markdown]
# # Quality Aspect - Reliability
# ## Factor - Testing Status

# %% [markdown]
# ##### Passed tests

# %%
def m4(df):

    passed_tests = df['test_success_density'].astype(float).median() / 100

    return passed_tests

# %% [markdown]
# ##### Fast test builds

# %%
def m5(df):

    density_fast_test_builds = len(df[(df['test_execution_time'].astype(float)) < 300]) / sum(df['tests'].astype(float))

    return density_fast_test_builds

# %% [markdown]
# ##### Test coverage

# %%
def m6(df):

    density_test_coverage = len(df[(df['coverage'].astype(float) > 60)]) / len(df)

    return density_test_coverage

# %% [markdown]
# ### Calculate m1, m2, m3, m4, m5 and m6 for each repository

# %%
def create_metrics_df(df):
    
    version_vec = df['version'].unique()
    
    m1_list = []
    m2_list = []
    m3_list = []
    m4_list = []
    m5_list = []
    m6_list = []

    ncloc_list = []
    repository_list = []
    version_list = []
    
    metrics_df = pd.DataFrame()
    
    for version in version_vec:

        version_df = df[df['version'] == version]

        m1_list.append(m1(version_df))
        m2_list.append(m2(version_df))
        m3_list.append(m3(version_df))
        m4_list.append(m3(version_df))
        m5_list.append(m3(version_df))
        m6_list.append(m3(version_df))

        ncloc_list.append(_ncloc(version_df))
        repository_list.append(version_df['repository'].iloc[0])
        version_list.append(version)
        
    metrics_df = pd.DataFrame({'m1': m1_list,
                               'm2': m2_list,
                               'm3': m3_list,
                               'm4': m3_list,
                               'm5': m3_list,
                               'm6': m3_list,
                               'repository': repository_list, 
                               'version': version_list,
                               'ncloc': ncloc_list
                              })
        
    return metrics_df

# %%
repository_metrics = {}

for repository, repo_df in repository_dataframes.items():   
    metrics_df = create_metrics_df(repo_df)
    metrics_df.name = f"{repository}"
    repository_metrics[f"{repository}"] = metrics_df
    
repository_dataframes.keys()
# Out:
# dict_keys(['2021.1-Cartografia-social-api-comunidades', '2021.1-Cartografia-social-api-gateway', '2021.1-Cartografia-social-api-mapas', '2021.1-Cartografia-social-api-midia', '2021.1-Cartografia-social-api-users', '2021.1-Cartografia-social-front'])

# %%
api_comunidades_metrics = create_metrics_df(api_comunidades_df)
api_gateway_metrics = create_metrics_df(api_gateway_df)
api_mapas_metrics = create_metrics_df(api_mapas_df)
api_midia_metrics = create_metrics_df(api_midia_df)
api_users_metrics = create_metrics_df(api_users_df)
#front_metrics = create_metrics_df(front_df)
...
# Out:
# Ellipsis

# %%
all_metrics = pd.concat([api_comunidades_metrics, api_gateway_metrics, api_mapas_metrics, api_midia_metrics, api_users_metrics], ignore_index=True)

# %% [markdown]
# ### Data visualization of [Maintainability e Reliability]
#
# - You must do this for each of your repositories

# %% [markdown]
# ## Descriptive Statistic Analysis
#
# - Realizes the calculation of statistic data such as mean, median, mode, min, max, standard deviation and variance.

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(api_comunidades_metrics['m1'], linewidth=3, marker='o', markersize=10)
plt.plot(api_comunidades_metrics['m2'], linewidth=3, marker='o', markersize=10)
plt.plot(api_comunidades_metrics['m3'], linewidth=3, marker='o', markersize=10)
plt.plot(api_comunidades_metrics['m4'], linewidth=3, marker='o', markersize=10)
plt.plot(api_comunidades_metrics['m5'], linewidth=3, marker='o', markersize=10)
plt.plot(api_comunidades_metrics['m6'], linewidth=3, marker='o', markersize=10)

# %%
#plot history
def plot_history(df, repository):
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:COMPLEXITY")
    plt.plot(df['m1'], linewidth=3, marker='o', markersize=10)
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:COMMENTS")
    plt.plot(df['m2'], linewidth=3, marker='o', markersize=10)
    fig = plt.figure(figsize=(20, 10))
    plt.title(f"{repository}:DUPLICATIONS")
    plt.plot(df['m3'], linewidth=3, marker='o', markersize=10)

# %%
generic_df = api_comunidades_metrics.copy()
repository = "API-COMUNIDADES"

# %%
plot_history(generic_df, repository)

# %%
fig = plt.figure(figsize=(20, 10))

plt.plot(repo2['m1'], linewidth=3, marker='o', markersize=10)
plt.plot(repo2['m2'], linewidth=3, marker='o', markersize=10)
plt.plot(repo2['m3'], linewidth=3, marker='o', markersize=10)
plt.plot(repo2['m4'], linewidth=3, marker='o', markersize=10)
plt.plot(repo2['m5'], linewidth=3, marker='o', markersize=10)
plt.plot(repo2['m6'], linewidth=3, marker='o', markersize=10)

...

# %% [markdown]
# ### Sub characteristic aggregation
#
# - You must do this for each of your repositories

# %%
psc1, psc2 = 1
pc1, pc2 = 0.5
pm1 = 0.33
pm2 = 0.33
pm3 = 0.33
pm4 = 0.15
pm5 = 0.15
pm6 = 0.7

repo1['code_quality'] = ((repo1['m1']*pm1) + (repo1['m2']*pm2) + (repo1['m3']*pm3)) * psc1
repo2['code_quality'] = ((repo2['m1']*pm1) + (repo2['m2']*pm2) + (repo2['m3']*pm3)) * psc1
...

repo1['testing_status'] = ((repo1['m4']*pm4) + (repo1['m5']*pm5) + (repo1['m6']*pm6)) * psc2
repo2['testing_status'] = ((repo2['m4']*pm4) + (repo2['m5']*pm5) + (repo2['m6']*pm6)) * psc2
...

# %%
fig = plt.figure(figsize=(20, 10))


plt.plot(repo1['code_quality'], linewidth=3, marker='o', markersize=5)
plt.plot(repo2['code_quality'], linewidth=3, marker='o', markersize=5)
...

# %%
fig = plt.figure(figsize=(20, 10))


plt.plot(repo1['testing_status'], linewidth=3, marker='o', markersize=5)
plt.plot(repo2['testing_status'], linewidth=3, marker='o', markersize=5)
...

# %%
metrics_df = pd.concat([repo1_metrics, repo2_metrics, ...], ignore_index=True)

metrics_df['maintainability'] = metrics_df['code_quality'] * pc1
metrics_df['Reliability'] = metrics_df['testing_status'] * pc2
metrics_df['total'] = metrics_df['maintainability'] + metrics_df['Reliability']

# %%
metrics_df

# %%
fig = plt.figure(figsize=(20, 10))


plt.plot(metrics_df['maintainability'], linewidth=3, marker='o', markersize=5)
plt.plot(metrics_df['Reliability'], linewidth=3, marker='o', markersize=5)


plt.ylim(.45,.7)

# %%
fig = plt.figure(figsize=(20, 10))


plt.plot(metrics_df['total'], linewidth=3, marker='o', markersize=5)


plt.ylim(.45,.7)

# %%
# ANALYSIS_DATE FORMAT: MM-DD-YYYY

metrics_df.to_excel('data/fga-eps-mds-2021_1-Cartografia-Social-ANALYSYS.xlsx', index = False)
metrics_df.to_csv('data/fga-eps-mds-2021_1-Cartografia-Social-ANALYSYS.csv', index = False)
